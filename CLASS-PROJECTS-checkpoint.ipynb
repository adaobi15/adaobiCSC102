# %% [markdown]
# ### NAME: ARINZECHI ADAOBI FAVOUR
# ### MAT . NO : 21120612451
# #### EMAIL: arinzechiadaobiada@gmail.com

# %% [markdown]
# ## PROJECT 1

# %% [markdown]
# ### pseduocode
# ### START
# #### INPUT num = n
# #### IF n > 17
# #### OUTPUT a = n -17
# #### PRINT num * 2
# #### ELSE
# #### OUTPUT b = n - 17
# #### PRINT num * 2
# ### END

# %%
n = int(input("enter a number"))
if n > 17:
    a = n - 17
    print(n * 2) 
else:
    b = n - 17
    print(n)

# %% [markdown]
# ![Picture1.png](attachment:Picture1.png)

# %% [markdown]
# ### PROJECT II

# %% [markdown]
# ### PSEUDOCODE
# ### START
# #### INPUT a, b, c
# #### x = a + b + c
# #### IF a==b , b==c, c==a
# #### OUTPUT (x * 3)
# #### ELSE
# #### PRINT (x)
# ### END

# %%
a = int(input("number ="))
b = int(input("number ="))
c = int(input("number ="))

x = a + b + c 
if a == b and  b == c and c == a:
    print(x * 3)
else:
    print(x)
# Out:
# number =3
# number =3
# number =3
# 27

# %% [markdown]
# ![Picture2.png](attachment:Picture2.png)

# %% [markdown]
# ### PROJECT III

# %% [markdown]
# ### PSEUDOCODE
# ### START
# #### INPUT a,b
# #### x = a + b,z = a - b
# #### IF x == 5  or z == 5  or  a == b
# #### OUTPUT (true)
# #### ELSE
# #### PRINT (false)
# ### END

# %%
a = int(input("enter a number"))
b = int(input("enter a number"))
x = a + b
z = a - b
if x == 5  or z == 5  or  a == b:
    print("true")
else:
    print("false")
# Out:
# enter a number4
# enter a number4
# true

# %% [markdown]
# ![Picture3.png](attachment:Picture3.png)

# %% [markdown]
# ### PROJECT IV

# %% [markdown]
# ### PSEUDOCODE
# ### START
# #### INPUT a, b, c
# #### x1 = max(a, b, c)  and    x2 = min(a, b, c)     and   x3 = (a + b + c) - x1 - x2
# ### END

# %%
a = int(input("input number"))
b = int(input("input number"))
c = int(input("input number"))

x1 = max(a, b, c)
x2 = min(a, b, c)
x3 = (a + b + c) - x1 - x2 

print(x1, x2 , x3)
# Out:
# input number1
# input number1
# input number2
# 2 1 1

# %% [markdown]
# ![Picture4.png](attachment:Picture4.png)

# %% [markdown]
# ### PROJECT V

# %% [markdown]
# ### PSEUDOCODE
# ### START
# #### IF a < 6
# #### OUTPUT a**a
# #### ELSE
# #### PRINT a
# ### END

# %%
a = int(input("input number"))
if a < 6: 
    print(a ** a)
else:
    a > 6
    print(a)
# Out:
# input number4
# smaller number 256

# %% [markdown]
# ![Picture5.png](attachment:Picture5.png)
